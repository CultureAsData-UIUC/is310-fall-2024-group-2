# %%
---
name: Project Manager Weekly Report
about: Template for project managers to report their weekly progress
title: "[Weekly Report] Project Manager for {5}"
labels: weekly-report
assignees: 
    Lhaye D.
    Aditi D.
    Ryan P.
    Avery W.
    Henry R.
    Rebeca R.
---
This is a template for project managers to report their weekly progress. Please fill out the following sections. You can also include any additional information that you think is relevant.

# Project Manager Weekly Report

## Weekly Checklist

- [x] Created a weekly report for the group project
- [x] Updated the project board
- [x] Checked in with team members
- [x] Assigned tasks for the upcoming week
- [x] Close issue once the weekly tasks are completed

## Weekly Summary:
*Try to answer the following questions as best you can, though you are welcome to keep it brief and in bullet points.*

- What were the goals for this week for the group project?
    Assign tasks to team members for the Critical Cultural Data Exporations assignment
    Create a deadline for the tasks to complete it in a timely manner     
    Check in with team members in regards to their progress on the assignment 

- What has been accomplished?
    Tasks have been assigned to team members 
    Deadlines have been set for the tasks 
    Team members have been checked in with in regards to their progress on the assignment
- Any problems or issues that need resolving?
    When looking for datasets, there were some difficulites with AI reading the historical dataset
    This created issues with the second part of the group assingment as the dataset was blocked and unreadable by the AI

## Next Week's Goals:
*Try to answer the following questions as best you can, though you are welcome to keep it brief and in bullet points.*

- What are the goals for the upcoming week?
    Find other options for the historical dataset or create one of our own from the information found on the historical dataset
    Rotate roles for the next assignment
    Create new deadlines for the next assignment
    Update Google doc with new information 
- Who is assigned to what tasks?
    Lhaye D. - Answer the question about the Timeline for the proposal
    Aditi D. - Answer the question about the Materials needed for the proposal
    Ryan P. - Answer the question about the Materials needed for the proposal
    Avery W. - Answer the question about the Division of Labor needed for the proposal
    Henry R. - Answer the question about the Topic for the proposal and answer the first 2 questions for teh Critical Cultural Data Explorations assignment
    Rebeca R. - Answer the last 2 questions and complete part 2 for the Critical Cultural Data Explorations assignment
## Notes/Additional Information:
*Optional additional information*
This is a good start! 

- Anything else to highlight?
The AI not being able to read the database was a big issue that we will need to address for the next assignment
